# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha1732/Nlp/blob/main/NLP%20Lab%20Assignment%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## TASK #**02**

# %%
SRUniversity="""The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana, India.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indias largest Technology Business Incubator (TBI) in tier 2 cities."""

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
SRUniversity="""The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana, India.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indias largest Technology Business Incubator (TBI) in tier 2 cities."""
tokens = nltk.word_tokenize(SRUniversity)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(SRUniversity)
for token in doc:
  print(token.text, token.pos_)
# Out:
# The DET
# SR PROPN
# University PROPN
# campus NOUN
# is AUX
# located VERB
# in ADP
# Ananthasagar PROPN
# village NOUN
# of ADP
# Hasanparthy PROPN
# Mandal PROPN
# in ADP
# Warangal PROPN
# , PUNCT
# Telangana PROPN
# , PUNCT
# India PROPN
# . PUNCT
#
#  SPACE
# It PRON
# is AUX
# in ADP
# 150 NUM
# acres NOUN
# , PUNCT
# with ADP
# both DET
# separate ADJ
# hostel NOUN
# facilities NOUN
# for ADP
# boys NOUN
# and CCONJ
# girls NOUN
# . PUNCT
#
#  SPACE
# There PRON
# is VERB
# a DET
# huge ADJ
# central ADJ
# library NOUN
# along ADP
# with ADP
# Indias PROPN
# largest ADJ
# Technology PROPN
# Business PROPN
# Incubator PROPN
# ( PUNCT
# TBI PROPN
# ) PUNCT
# in ADP
# tier NOUN
# 2 NUM
# cities NOUN
# . PUNCT

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(SRUniversity)
for token in doc:
  print(token.text, token.pos_, token.tag_)
# Out:
# The DET DT
# SR PROPN NNP
# University PROPN NNP
# campus NOUN NN
# is AUX VBZ
# located VERB VBN
# in ADP IN
# Ananthasagar PROPN NNP
# village NOUN NN
# of ADP IN
# Hasanparthy PROPN NNP
# Mandal PROPN NNP
# in ADP IN
# Warangal PROPN NNP
# , PUNCT ,
# Telangana PROPN NNP
# , PUNCT ,
# India PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# It PRON PRP
# is AUX VBZ
# in ADP IN
# 150 NUM CD
# acres NOUN NNS
# , PUNCT ,
# with ADP IN
# both DET DT
# separate ADJ JJ
# hostel NOUN NN
# facilities NOUN NNS
# for ADP IN
# boys NOUN NNS
# and CCONJ CC
# girls NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# There PRON EX
# is VERB VBZ
# a DET DT
# huge ADJ JJ
# central ADJ JJ
# library NOUN NN
# along ADP IN
# with ADP IN
# Indias PROPN NNP
# largest ADJ JJS
# Technology PROPN NNP
# Business PROPN NNP
# Incubator PROPN NNP
# ( PUNCT -LRB-
# TBI PROPN NNP
# ) PUNCT -RRB-
# in ADP IN
# tier NOUN NN
# 2 NUM CD
# cities NOUN NNS
# . PUNCT .

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
doc = nlp(SRUniversity)
nouns = []
verbs = []
for token in doc:
  if token.pos_ in ["NOUN", "PROPN"]:
    nouns.append(token.text)
  elif token.pos_ == "VERB":
    verbs.append(token.text)
noun_freq = Counter(nouns)
verb_freq = Counter(verbs)
print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'SR': 1, 'University': 1, 'campus': 1, 'Ananthasagar': 1, 'village': 1, 'Hasanparthy': 1, 'Mandal': 1, 'Warangal': 1, 'Telangana': 1, 'India': 1, 'acres': 1, 'hostel': 1, 'facilities': 1, 'boys': 1, 'girls': 1, 'library': 1, 'Indias': 1, 'Technology': 1, 'Business': 1, 'Incubator': 1, 'TBI': 1, 'tier': 1, 'cities': 1})
# Verb Frequency: Counter({'located': 1, 'is': 1})

# %% [markdown]
# # TASK #**01**

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
Sentence="Students are learning Natural Language Processing"
tokens = nltk.word_tokenize(Sentence)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('The', 'DT'), ('SR', 'NNP'), ('University', 'NNP'), ('campus', 'NN'), ('is', 'VBZ'), ('located', 'VBN'), ('in', 'IN'), ('Ananthasagar', 'NNP'), ('village', 'NN'), ('of', 'IN'), ('Hasanparthy', 'NNP'), ('Mandal', 'NNP'), ('in', 'IN'), ('Warangal', 'NNP'), (',', ','), ('Telangana', 'NNP'), (',', ','), ('India', 'NNP'), ('.', '.'), ('It', 'PRP'), ('is', 'VBZ'), ('in', 'IN'), ('150', 'CD'), ('acres', 'NNS'), (',', ','), ('with', 'IN'), ('both', 'DT'), ('separate', 'JJ'), ('hostel', 'NN'), ('facilities', 'NNS'), ('for', 'IN'), ('boys', 'NNS'), ('and', 'CC'), ('girls', 'NNS'), ('.', '.'), ('There', 'EX'), ('is', 'VBZ'), ('a', 'DT'), ('huge', 'JJ'), ('central', 'JJ'), ('library', 'NN'), ('along', 'IN'), ('with', 'IN'), ('Indias', 'NNP'), ('largest', 'JJS'), ('Technology', 'NN'), ('Business', 'NNP'), ('Incubator', 'NNP'), ('(', '('), ('TBI', 'NNP'), (')', ')'), ('in', 'IN'), ('tier', '$'), ('2', 'CD'), ('cities', 'NNS'), ('.', '.')]
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Students are learning Natural Language Processing")
for token in doc:
  print(token.text, token.pos_)
# Out:
# Students NOUN
# are AUX
# learning VERB
# Natural PROPN
# Language PROPN
# Processing NOUN

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying a startup in India.")
for token in doc:
  print(token.text, token.pos_, token.tag_)
# Out:
# Apple PROPN NNP
# is AUX VBZ
# looking VERB VBG
# at ADP IN
# buying VERB VBG
# a DET DT
# startup NOUN NN
# in ADP IN
# India PROPN NNP
# . PUNCT .

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
text = "Loving the new AI features  #AI #MachineLearning"
doc = nlp(text)
nouns = []
verbs = []
for token in doc:
  if token.pos_ in ["NOUN", "PROPN"]:
    nouns.append(token.text)
  elif token.pos_ == "VERB":
    verbs.append(token.text)
noun_freq = Counter(nouns)
verb_freq = Counter(verbs)
print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'AI': 2, 'MachineLearning': 1})
# Verb Frequency: Counter({'Loving': 1, 'features': 1})

# %% [markdown]
# # TASK #**03**

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
text="Technology shapes modern life by connecting people, ideas, and opportunities across the world. Students learn faster using digital tools, online libraries, and interactive platforms. Communication has become instant through messages, video calls, and social networks. Businesses grow by analyzing data, automating tasks, and reaching global customers. Healthcare improves with smart devices, artificial intelligence, and remote consultations. Education adapts through virtual classrooms and personalized learning. While challenges like privacy and addiction exist, responsible use creates balance. Innovation continues to transform society, encouraging creativity, collaboration, and problem solving for a smarter, inclusive future for everyone worldwide today with hope and responsibility together"
tokens = nltk.word_tokenize(text)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('Technology', 'NNP'), ('shapes', 'VBZ'), ('modern', 'JJ'), ('life', 'NN'), ('by', 'IN'), ('connecting', 'VBG'), ('people', 'NNS'), (',', ','), ('ideas', 'NNS'), (',', ','), ('and', 'CC'), ('opportunities', 'NNS'), ('across', 'IN'), ('the', 'DT'), ('world', 'NN'), ('.', '.'), ('Students', 'NNS'), ('learn', 'VBP'), ('faster', 'JJR'), ('using', 'VBG'), ('digital', 'JJ'), ('tools', 'NNS'), (',', ','), ('online', 'JJ'), ('libraries', 'NNS'), (',', ','), ('and', 'CC'), ('interactive', 'JJ'), ('platforms', 'NNS'), ('.', '.'), ('Communication', 'NN'), ('has', 'VBZ'), ('become', 'VBN'), ('instant', 'JJ'), ('through', 'IN'), ('messages', 'NNS'), (',', ','), ('video', 'NN'), ('calls', 'NNS'), (',', ','), ('and', 'CC'), ('social', 'JJ'), ('networks', 'NNS'), ('.', '.'), ('Businesses', 'NNS'), ('grow', 'VBP'), ('by', 'IN'), ('analyzing', 'VBG'), ('data', 'NNS'), (',', ','), ('automating', 'VBG'), ('tasks', 'NNS'), (',', ','), ('and', 'CC'), ('reaching', 'VBG'), ('global', 'JJ'), ('customers', '
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Technology shapes modern life by connecting people, ideas, and opportunities across the world. Students learn faster using digital tools, online libraries, and interactive platforms. Communication has become instant through messages, video calls, and social networks. Businesses grow by analyzing data, automating tasks, and reaching global customers. Healthcare improves with smart devices, artificial intelligence, and remote consultations. Education adapts through virtual classrooms and personalized learning. While challenges like privacy and addiction exist, responsible use creates balance. Innovation continues to transform society, encouraging creativity, collaboration, and problem solving for a smarter, inclusive future for everyone worldwide today with hope and responsibility together")
for token in doc:
  print(token.text, token.pos_)
# Out:
# Technology NOUN
# shapes VERB
# modern ADJ
# life NOUN
# by ADP
# connecting VERB
# people NOUN
# , PUNCT
# ideas NOUN
# , PUNCT
# and CCONJ
# opportunities NOUN
# across ADP
# the DET
# world NOUN
# . PUNCT
# Students NOUN
# learn VERB
# faster ADV
# using VERB
# digital ADJ
# tools NOUN
# , PUNCT
# online ADJ
# libraries NOUN
# , PUNCT
# and CCONJ
# interactive ADJ
# platforms NOUN
# . PUNCT
# Communication NOUN
# has AUX
# become VERB
# instant ADJ
# through ADP
# messages NOUN
# , PUNCT
# video NOUN
# calls NOUN
# , PUNCT
# and CCONJ
# social ADJ
# networks NOUN
# . PUNCT
# Businesses NOUN
# grow VERB
# by ADP
# analyzing VERB
# data NOUN
# , PUNCT
# automating VERB
# tasks NOUN
# , PUNCT
# and CCONJ
# reaching VERB
# global ADJ
# customers NOUN
# . PUNCT
# Healthcare PROPN
# improves VERB
# with ADP
# smart ADJ
# devices NOUN
# , PUNCT
# artificial ADJ
# intelligence NOUN
# , PUNCT
# and CCONJ
# remote ADJ
# consultations NOUN
# . PUNCT
# Education NOUN
# adapts VERB
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Technology shapes modern life by connecting people, ideas, and opportunities across the world. Students learn faster using digital tools, online libraries, and interactive platforms. Communication has become instant through messages, video calls, and social networks. Businesses grow by analyzing data, automating tasks, and reaching global customers. Healthcare improves with smart devices, artificial intelligence, and remote consultations. Education adapts through virtual classrooms and personalized learning. While challenges like privacy and addiction exist, responsible use creates balance. Innovation continues to transform society, encouraging creativity, collaboration, and problem solving for a smarter, inclusive future for everyone worldwide today with hope and responsibility together")
for token in doc:
  print(token.text, token.pos_, token.tag_)
# Out:
# Technology NOUN NN
# shapes VERB VBZ
# modern ADJ JJ
# life NOUN NN
# by ADP IN
# connecting VERB VBG
# people NOUN NNS
# , PUNCT ,
# ideas NOUN NNS
# , PUNCT ,
# and CCONJ CC
# opportunities NOUN NNS
# across ADP IN
# the DET DT
# world NOUN NN
# . PUNCT .
# Students NOUN NNS
# learn VERB VBP
# faster ADV RBR
# using VERB VBG
# digital ADJ JJ
# tools NOUN NNS
# , PUNCT ,
# online ADJ JJ
# libraries NOUN NNS
# , PUNCT ,
# and CCONJ CC
# interactive ADJ JJ
# platforms NOUN NNS
# . PUNCT .
# Communication NOUN NN
# has AUX VBZ
# become VERB VBN
# instant ADJ JJ
# through ADP IN
# messages NOUN NNS
# , PUNCT ,
# video NOUN NN
# calls NOUN NNS
# , PUNCT ,
# and CCONJ CC
# social ADJ JJ
# networks NOUN NNS
# . PUNCT .
# Businesses NOUN NNS
# grow VERB VBP
# by ADP IN
# analyzing VERB VBG
# data NOUN NNS
# , PUNCT ,
# automating VERB VBG
# tasks NOUN NNS
# , PUNCT ,
# and CCONJ CC
# reaching VERB VBG
# global ADJ JJ
# customers NOUN NNS
# . PUNCT .
# Healthcare PROPN NNP
# ...

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
text = "Loving the new AI features  #AI #MachineLearning"
doc = nlp("Technology shapes modern life by connecting people, ideas, and opportunities across the world. Students learn faster using digital tools, online libraries, and interactive platforms. Communication has become instant through messages, video calls, and social networks. Businesses grow by analyzing data, automating tasks, and reaching global customers. Healthcare improves with smart devices, artificial intelligence, and remote consultations. Education adapts through virtual classrooms and personalized learning. While challenges like privacy and addiction exist, responsible use creates balance. Innovation continues to transform society, encouraging creativity, collaboration, and problem solving for a smarter, inclusive future for everyone worldwide today with hope and responsibility together")
nouns = []
verbs = []
for token in doc:
  if token.pos_ in ["NOUN", "PROPN"]:
    nouns.append(token.text)
  elif token.pos_ == "VERB":
    verbs.append(token.text)
noun_freq = Counter(nouns)
verb_freq = Counter(verbs)
print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'Technology': 1, 'life': 1, 'people': 1, 'ideas': 1, 'opportunities': 1, 'world': 1, 'Students': 1, 'tools': 1, 'libraries': 1, 'platforms': 1, 'Communication': 1, 'messages': 1, 'video': 1, 'calls': 1, 'networks': 1, 'Businesses': 1, 'data': 1, 'tasks': 1, 'customers': 1, 'Healthcare': 1, 'devices': 1, 'intelligence': 1, 'consultations': 1, 'Education': 1, 'classrooms': 1, 'learning': 1, 'challenges': 1, 'privacy': 1, 'addiction': 1, 'use': 1, 'balance': 1, 'Innovation': 1, 'society': 1, 'creativity': 1, 'collaboration': 1, 'problem': 1, 'future': 1, 'today': 1, 'hope': 1, 'responsibility': 1})
# Verb Frequency: Counter({'shapes': 1, 'connecting': 1, 'learn': 1, 'using': 1, 'become': 1, 'grow': 1, 'analyzing': 1, 'automating': 1, 'reaching': 1, 'improves': 1, 'adapts': 1, 'exist': 1, 'creates': 1, 'continues': 1, 'transform': 1, 'encouraging': 1, 'solving': 1})
